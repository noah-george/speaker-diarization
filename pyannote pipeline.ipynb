# %%
# !pip install -qq pyannote.audio==2.1.1
# !pip install -qq rich

# %%
# !pip install pyannote.database
# Out:
# Requirement already satisfied: pyannote.database in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (4.1.3)
# Requirement already satisfied: pyYAML>=3.12 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.database) (6.0)
# Requirement already satisfied: pandas>=0.19 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.database) (1.5.3)
# Requirement already satisfied: typer[all]>=0.2.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.database) (0.7.0)
# Requirement already satisfied: pyannote.core>=4.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.database) (4.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pandas>=0.19->pyannote.database) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pandas>=0.19->pyannote.database) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pandas>=0.19->pyannote.database) (2022.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.core>=4.1->pyannote.database) (4.4.0)
# Requirement already satisfied: simplejson>=3.8.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.core>=4.1->pyannote.database) (3.18.3)
# Requirement already satisfied: scipy>=1.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.core>=4.1->pyannote.database) (1.10.1)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from pyannote.core>=4.1->pyannote.database) (2.4.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from typer[all]>=0.2.1->pyannote.database) (8.1.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from typer[all]>=0.2.1->pyannote.database) (0.4.6)
# Requirement already satisfied: rich<13.0.0,>=10.11.0 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from typer[all]>=0.2.1->pyannote.database) (12.6.0)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from typer[all]>=0.2.1->pyannote.database) (1.5.0.post1)
# Requirement already satisfied: six>=1.5 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pyannote.database) (1.16.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database) (2.14.0)

# %%
# %cd ~/Downloads/content/
# !git clone https://github.com/pyannote/AMI-diarization-setup
# %cd ~/Downloads/content/AMI-diarization-setup/pyannote/
# !bash download_ami_sdm.sh
# Out:
# /home/user/Downloads/content
# fatal: destination path 'AMI-diarization-setup' already exists and is not an empty directory.
# /home/user/Downloads/content/AMI-diarization-setup/pyannote
# ES2002b.Array1-01.w 100%[===================>]  69.57M  4.98MB/s    in 18s
# 2023-02-28 12:40:18 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2002b/audio/ES2002b.Array1-01.wav [72952194/72952194] -> "amicorpus/ES2002b/audio/ES2002b.Array1-01.wav" [1]
# ES2002c.Array1-01.w 100%[===================>]  73.97M  5.58MB/s    in 19s
# 2023-02-28 12:40:39 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2002c/audio/ES2002c.Array1-01.wav [77558826/77558826] -> "amicorpus/ES2002c/audio/ES2002c.Array1-01.wav" [1]
# ES2002d.Array1-01.w 100%[===================>]  80.08M  5.14MB/s    in 26s
# 2023-02-28 12:41:06 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2002d/audio/ES2002d.Array1-01.wav [83974526/83974526] -> "amicorpus/ES2002d/audio/ES2002d.Array1-01.wav" [1]
# ES2003b.Array1-01.w 100%[===================>]  64.39M  4.89MB/s    in 19s
# 2023-02-28 12:41:28 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2003b/audio/ES2003b.Array1-01.wav [67514072/67514072] -> "amicorpus/ES2003b/audio/ES2003b.Array1-01.wav" [1]
# ES2003c.Array1-01.w 100%[===================>]  68.88M  4.96MB/s    in 23s
# 2023-02-28 12:41:52 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2003c/audio/ES2003c.Array1-01.wav [72221740/72221740] -> "amicorpus/ES2003c/audio/ES2003c.Array1-01.wav" [1]
# ES2003d.Array1-01.w 100%[===================>]  71.75M  5.61MB/s    in 19s
# 2023-02-28 12:42:12 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2003d/audio/ES2003d.Array1-01.wav [75232984/75232984] -> "amicorpus/ES2003d/audio/ES2003d.Array1-01.wav" [1]
# ES2004b.Array1-01.w 100%[===================>]  71.58M  5.98MB/s    in 25s
# 2023-02-28 12:42:39 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2004b/audio/ES2004b.Array1-01.wav [75055832/75055832] -> "amicorpus/ES2004b/audio/ES2004b.Array1-01.wav" [1]
# ES2004c.Array1-01.w 100%[===================>]  71.24M  5.04MB/s    in 26s
# 2023-02-28 12:43:06 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2004c/audio/ES2004c.Array1-01.wav [74699820/74699820] -> "amicorpus/ES2004c/audio/ES2004c.Array1-01.wav" [1]
# ES2004d.Array1-01.w 100%[===================>]  67.82M  5.27MB/s    in 19s
# 2023-02-28 12:43:27 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2004d/audio/ES2004d.Array1-01.wav [71113346/71113346] -> "amicorpus/ES2004d/audio/ES2004d.Array1-01.wav" [1]
# ES2005b.Array1-01.w 100%[===================>]  70.59M  5.04MB/s    in 24s
# 2023-02-28 12:43:54 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2005b/audio/ES2005b.Array1-01.wav [74024322/74024322] -> "amicorpus/ES2005b/audio/ES2005b.Array1-01.wav" [1]
# ES2005c.Array1-01.w 100%[===================>]  70.07M  5.84MB/s    in 19s
# 2023-02-28 12:44:14 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2005c/audio/ES2005c.Array1-01.wav [73468972/73468972] -> "amicorpus/ES2005c/audio/ES2005c.Array1-01.wav" [1]
# ES2005d.Array1-01.w 100%[===================>]  52.83M  5.03MB/s    in 17s
# 2023-02-28 12:44:32 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2005d/audio/ES2005d.Array1-01.wav [55397762/55397762] -> "amicorpus/ES2005d/audio/ES2005d.Array1-01.wav" [1]
# ES2006b.Array1-01.w 100%[===================>]  66.62M  5.21MB/s    in 20s
# 2023-02-28 12:44:54 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2006b/audio/ES2006b.Array1-01.wav [69860056/69860056] -> "amicorpus/ES2006b/audio/ES2006b.Array1-01.wav" [1]
# ES2006c.Array1-01.w 100%[===================>]  66.58M  5.72MB/s    in 19s
# 2023-02-28 12:45:14 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2006c/audio/ES2006c.Array1-01.wav [69813976/69813976] -> "amicorpus/ES2006c/audio/ES2006c.Array1-01.wav" [1]
# ES2006d.Array1-01.w 100%[===================>]  60.04M  5.33MB/s    in 18s
# 2023-02-28 12:45:34 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2006d/audio/ES2006d.Array1-01.wav [62958296/62958296] -> "amicorpus/ES2006d/audio/ES2006d.Array1-01.wav" [1]
# ES2007b.Array1-01.w 100%[===================>]  51.43M  5.00MB/s    in 16s
# 2023-02-28 12:45:52 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2007b/audio/ES2007b.Array1-01.wav [53931052/53931052] -> "amicorpus/ES2007b/audio/ES2007b.Array1-01.wav" [1]
# ES2007c.Array1-01.w 100%[===================>]  72.55M  5.48MB/s    in 19s
# 2023-02-28 12:46:12 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2007c/audio/ES2007c.Array1-01.wav [76077100/76077100] -> "amicorpus/ES2007c/audio/ES2007c.Array1-01.wav" [1]
# ES2007d.Array1-01.w 100%[===================>]  38.13M  4.23MB/s    in 15s
# 2023-02-28 12:46:28 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2007d/audio/ES2007d.Array1-01.wav [39984514/39984514] -> "amicorpus/ES2007d/audio/ES2007d.Array1-01.wav" [1]
# ES2008b.Array1-01.w 100%[===================>]  68.10M  5.41MB/s    in 18s
# 2023-02-28 12:46:49 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES
URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2012b/audio/ES2012b.Array1-01.wav [71669378/71669378] -> "amicorpus/ES2012b/audio/ES2012b.Array1-01.wav" [1]
# ES2012c.Array1-01.w 100%[===================>]  67.40M  5.85MB/s    in 17s
# 2023-02-28 12:50:44 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2012c/audio/ES2012c.Array1-01.wav [70678232/70678232] -> "amicorpus/ES2012c/audio/ES2012c.Array1-01.wav" [1]
# ES2012d.Array1-01.w 100%[===================>]  28.98M  4.05MB/s    in 11s
# 2023-02-28 12:50:56 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2012d/audio/ES2012d.Array1-01.wav [30388952/30388952] -> "amicorpus/ES2012d/audio/ES2012d.Array1-01.wav" [1]
# ES2013b.Array1-01.w 100%[===================>]  64.96M  4.96MB/s    in 18s
# 2023-02-28 12:51:16 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2013b/audio/ES2013b.Array1-01.wav [68116184/68116184] -> "amicorpus/ES2013b/audio/ES2013b.Array1-01.wav" [1]
# ES2013c.Array1-01.w 100%[===================>]  71.96M  5.01MB/s    in 21s
# 2023-02-28 12:51:39 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2013c/audio/ES2013c.Array1-01.wav [75459970/75459970] -> "amicorpus/ES2013c/audio/ES2013c.Array1-01.wav" [1]
# ES2013d.Array1-01.w 100%[===================>]  57.94M  5.72MB/s    in 15s
# 2023-02-28 12:51:55 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2013d/audio/ES2013d.Array1-01.wav [60753964/60753964] -> "amicorpus/ES2013d/audio/ES2013d.Array1-01.wav" [1]
# ES2014b.Array1-01.w 100%[===================>]  70.80M  5.60MB/s    in 18s
# 2023-02-28 12:52:15 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2014b/audio/ES2014b.Array1-01.wav [74236632/74236632] -> "amicorpus/ES2014b/audio/ES2014b.Array1-01.wav" [1]
# ES2014c.Array1-01.w 100%[===================>]  69.38M  5.82MB/s    in 18s
# 2023-02-28 12:52:35 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2014c/audio/ES2014c.Array1-01.wav [72752856/72752856] -> "amicorpus/ES2014c/audio/ES2014c.Array1-01.wav" [1]
# ES2014d.Array1-01.w 100%[===================>]  88.85M  6.00MB/s    in 21s
# 2023-02-28 12:52:56 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2014d/audio/ES2014d.Array1-01.wav [93163564/93163564] -> "amicorpus/ES2014d/audio/ES2014d.Array1-01.wav" [1]
# ES2015b.Array1-01.w 100%[===================>]  70.03M  5.72MB/s    in 19s
# 2023-02-28 12:53:17 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2015b/audio/ES2015b.Array1-01.wav [73435522/73435522] -> "amicorpus/ES2015b/audio/ES2015b.Array1-01.wav" [1]
# ES2015c.Array1-01.w 100%[===================>]  65.18M  4.95MB/s    in 19s
# 2023-02-28 12:53:38 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2015c/audio/ES2015c.Array1-01.wav [68348632/68348632] -> "amicorpus/ES2015c/audio/ES2015c.Array1-01.wav" [1]
# ES2015d.Array1-01.w 100%[===================>]  58.95M  6.03MB/s    in 15s
# 2023-02-28 12:53:53 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2015d/audio/ES2015d.Array1-01.wav [61810050/61810050] -> "amicorpus/ES2015d/audio/ES2015d.Array1-01.wav" [1]
# ES2016b.Array1-01.w 100%[===================>]  73.62M  4.42MB/s    in 22s
# 2023-02-28 12:54:18 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES2016b/audio/ES2016b.Array1-01.wav [77191212/77191212] -> "amicorpus/ES2016b/audio/ES2016b.Array1-01.wav" [1]
# ES2016c.Array1-01.w 100%[===================>]  70.45M  5.62MB/s    in 17s
# 2023-02-28 12:54:36 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/ES
URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2002b/audio/EN2002b.Array1-01.wav [57179180/57179180] -> "amicorpus/EN2002b/audio/EN2002b.Array1-01.wav" [1]
# EN2002c.Array1-01.w 100%[===================>]  90.71M  5.91MB/s    in 20s
# 2023-02-28 13:14:55 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2002c/audio/EN2002c.Array1-01.wav [95112236/95112236] -> "amicorpus/EN2002c/audio/EN2002c.Array1-01.wav" [1]
# EN2002d.Array1-01.w 100%[===================>]  67.44M  6.16MB/s    in 15s
# 2023-02-28 13:15:11 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2002d/audio/EN2002d.Array1-01.wav [70716802/70716802] -> "amicorpus/EN2002d/audio/EN2002d.Array1-01.wav" [1]
# EN2003a.Array1-01.w 100%[===================>]  68.37M  5.86MB/s    in 16s
# 2023-02-28 13:15:28 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2003a/audio/EN2003a.Array1-01.wav [71688920/71688920] -> "amicorpus/EN2003a/audio/EN2003a.Array1-01.wav" [1]
# EN2004a.Array1-01.w 100%[===================>] 105.15M  6.18MB/s    in 21s
# 2023-02-28 13:15:51 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2004a/audio/EN2004a.Array1-01.wav [110261634/110261634] -> "amicorpus/EN2004a/audio/EN2004a.Array1-01.wav" [1]
# EN2005a.Array1-01.w 100%[===================>] 165.26M  6.19MB/s    in 31s
# 2023-02-28 13:16:23 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2005a/audio/EN2005a.Array1-01.wav [173287554/173287554] -> "amicorpus/EN2005a/audio/EN2005a.Array1-01.wav" [1]
# EN2006a.Array1-01.w 100%[===================>] 107.59M  5.94MB/s    in 22s
# 2023-02-28 13:16:47 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2006a/audio/EN2006a.Array1-01.wav [112815832/112815832] -> "amicorpus/EN2006a/audio/EN2006a.Array1-01.wav" [1]
# EN2006b.Array1-01.w 100%[===================>]  93.15M  6.04MB/s    in 20s
# 2023-02-28 13:17:08 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2006b/audio/EN2006b.Array1-01.wav [97672322/97672322] -> "amicorpus/EN2006b/audio/EN2006b.Array1-01.wav" [1]
# EN2009b.Array1-01.w 100%[===================>]  75.51M  6.17MB/s    in 16s
# 2023-02-28 13:17:25 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2009b/audio/EN2009b.Array1-01.wav [79177090/79177090] -> "amicorpus/EN2009b/audio/EN2009b.Array1-01.wav" [1]
# EN2009c.Array1-01.w 100%[===================>]  94.60M  6.13MB/s    in 20s
# 2023-02-28 13:17:46 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2009c/audio/EN2009c.Array1-01.wav [99199704/99199704] -> "amicorpus/EN2009c/audio/EN2009c.Array1-01.wav" [1]
# EN2009d.Array1-01.w 100%[===================>] 162.49M  5.81MB/s    in 31s
# 2023-02-28 13:18:18 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/EN2009d/audio/EN2009d.Array1-01.wav [170379992/170379992] -> "amicorpus/EN2009d/audio/EN2009d.Array1-01.wav" [1]
# IB4001.Array1-01.wa 100%[===================>]  54.35M  5.92MB/s    in 14s
# 2023-02-28 13:18:33 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IB4001/audio/IB4001.Array1-01.wav [56986418/56986418] -> "amicorpus/IB4001/audio/IB4001.Array1-01.wav" [1]
# IB4002.Array1-01.wa 100%[===================>]  57.45M  6.05MB/s    in 14s
# 2023-02-28 13:18:47 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/
URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IN1013/audio/IN1013.Array1-01.wav [100553602/100553602] -> "amicorpus/IN1013/audio/IN1013.Array1-01.wav" [1]
# IN1014.Array1-01.wa 100%[===================>] 112.70M  5.99MB/s    in 23s
# 2023-02-28 13:23:12 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IN1014/audio/IN1014.Array1-01.wav [118174594/118174594] -> "amicorpus/IN1014/audio/IN1014.Array1-01.wav" [1]
# IN1016.Array1-01.wa 100%[===================>] 110.00M  6.33MB/s    in 23s
# 2023-02-28 13:23:36 URL:https://groups.inf.ed.ac.uk/ami/AMICorpusMirror/amicorpus/IN1016/audio/IN1016.Array1-01.wav [115340162/115340162] -> "amicorpus/IN1016/audio/IN1016.Array1-01.wav" [1]

# %%
PYANNOTE_DATABASE_CONFIG="~/Downloads/content/AMI-diarization-setup/pyannote/database.yml" pyannote-database info AMI-SDM.SpeakerDiarization.mini
# Out:
# train
#    28 files
#    8h46m annotated
#    6h11m of speech (71%)
#    112 speakers
# development
#    3 files
#    0h56m annotated
#    0h40m of speech (72%)
#    12 speakers
# test
#    3 files
#    0h56m annotated
#    0h39m of speech (70%)
#    12 speakers

# %%
import os
os.environ["PYANNOTE_DATABASE_CONFIG"] = "~/Downloads/content/AMI-diarization-setup/pyannote/database.yml"
from pyannote.database import get_protocol, FileFinder, registry
from pyannote.database import registry

registry.load_database("~/Downloads/content/AMI-diarization-setup/pyannote/database.yml")

dataset = registry.get_protocol("AMI-SDM.SpeakerDiarization.mini", {"audio": FileFinder()})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[74], line 4
#       2 os.environ["PYANNOTE_DATABASE_CONFIG"] = "~/Downloads/content/AMI-diarization-setup/pyannote/database.yml"
#       3 from pyannote.database import get_protocol, FileFinder
# ----> 4 from pyannote.database import registry
#       6 registry.load_database("~/Downloads/content/AMI-diarization-setup/pyannote/database.yml")
#       8 dataset = registry.get_protocol("AMI-SDM.SpeakerDiarization.mini", {"audio": FileFinder()})
#
# ImportError: cannot import name 'registry' from 'pyannote.database' (/home/user/anaconda3/envs/pyannote/lib/python3.8/site-packages/pyannote/database/__init__.py)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from pyannote.audio import Pipeline
pretrained_pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization", use_auth_token=True)

# %%
from pyannote.metrics.diarization import DiarizationErrorRate
metric = DiarizationErrorRate()

for file in dataset.test():
    # apply pretrained pipeline
    file["pretrained pipeline"] = pretrained_pipeline(file)

    # evaluate its performance
    metric(file["annotation"], file["pretrained pipeline"], uem=file["annotated"])

print(f"The pretrained pipeline reaches a Diarization Error Rate (DER) of {100 * abs(metric):.1f}% on {dataset.name} test set.")

# %%
file["annotation"]

# %%
file["pretrained pipeline"]

# %%
from pyannote.audio import Model
model = Model.from_pretrained("pyannote/segmentation", use_auth_token=True)

# %%
from pyannote.audio.tasks import Segmentation
task = Segmentation(dataset, 
                    duration=model.specifications.duration, 
                    max_num_speakers=len(model.specifications.classes), 
                    batch_size=32,
                    num_workers=2, 
                    loss="bce", 
                    vad_loss="bce")
model.task = task
model.setup(stage="fit")

# %%
from types import MethodType
from torch.optim import Adam
from pytorch_lightning.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    RichProgressBar,
)

# we use Adam optimizer with 1e-4 learning rate
def configure_optimizers(self):
    return Adam(self.parameters(), lr=1e-4)

model.configure_optimizers = MethodType(configure_optimizers, model)

# we monitor diarization error rate on the validation set
# and use to keep the best checkpoint and stop early
monitor, direction = task.val_monitor
checkpoint = ModelCheckpoint(
    monitor=monitor,
    mode=direction,
    save_top_k=1,
    every_n_epochs=1,
    save_last=False,
    save_weights_only=False,
    filename="{epoch}",
    verbose=False,
)
early_stopping = EarlyStopping(
    monitor=monitor,
    mode=direction,
    min_delta=0.0,
    patience=10,
    strict=True,
    verbose=False,
)

callbacks = [RichProgressBar(), checkpoint, early_stopping]

# we train for at most 20 epochs (might be shorter in case of early stopping)
from pytorch_lightning import Trainer
trainer = Trainer(accelerator="gpu", 
                  callbacks=callbacks, 
                  max_epochs=20,
                  gradient_clip_val=0.5)
trainer.fit(model)

# %%
finetuned_model = checkpoint.best_model_path

# %%
pretrained_hyperparameters = pretrained_pipeline.parameters(instantiated=True)
pretrained_hyperparameters

# %%
from pyannote.audio.pipelines import SpeakerDiarization
from pyannote.pipeline import Optimizer

pipeline = SpeakerDiarization(
    segmentation=finetuned_model,
    clustering="OracleClustering",  
)
# as reported in the technical report, min_duration_off can safely be set to 0.0
pipeline.freeze({"segmentation": {"min_duration_off": 0.0}})

optimizer = Optimizer(pipeline)
dev_set = list(dataset.development())

iterations = optimizer.tune_iter(dev_set, show_progress=False)
best_loss = 1.0
for i, iteration in enumerate(iterations):
    print(f"Best segmentation threshold so far: {iteration['params']['segmentation']['threshold']}")
    if i > 20: break

# %%
best_segmentation_threshold = optimizer.best_params["segmentation"]["threshold"]

# %%
# this takes approximately 5min to run on Google Colab GPU
pipeline = SpeakerDiarization(
    segmentation=finetuned_model,
    embedding=pretrained_pipeline.embedding,
    embedding_exclude_overlap=pretrained_pipeline.embedding_exclude_overlap,
    clustering=pretrained_pipeline.klustering,
)

pipeline.freeze({
    "segmentation": {
        "threshold": best_segmentation_threshold,
        "min_duration_off": 0.0,
    },
    "clustering": {
        "method": "centroid",
        "min_cluster_size": 15,
    },
})

optimizer = Optimizer(pipeline)
iterations = optimizer.tune_iter(dev_set, show_progress=False)
best_loss = 1.0
for i, iteration in enumerate(iterations):
    print(f"Best clustering threshold so far: {iteration['params']['clustering']['threshold']}")
    if i > 20: break  # 50 iterations should give slightly better results

# %%
best_clustering_threshold = optimizer.best_params['clustering']['threshold']

# %%
inetuned_pipeline = SpeakerDiarization(
    segmentation=finetuned_model,
    embedding=pretrained_pipeline.embedding,
    embedding_exclude_overlap=pretrained_pipeline.embedding_exclude_overlap,
    clustering=pretrained_pipeline.klustering,
)

finetuned_pipeline.instantiate({
    "segmentation": {
        "threshold": best_segmentation_threshold,
        "min_duration_off": 0.0,
    },
    "clustering": {
        "method": "centroid",
        "min_cluster_size": 15,
        "threshold": best_clustering_threshold,
    },
})

metric = DiarizationErrorRate()

for file in dataset.test():
    # apply finetuned pipeline
    file["finetuned pipeline"] = finetuned_pipeline(file)

    # evaluate its performance
    metric(file["annotation"], file["finetuned pipeline"], uem=file["annotated"])

print(f"The finetuned pipeline reaches a Diarization Error Rate (DER) of {100 * abs(metric):.1f}% on {dataset.name} test set.")

# %%
file["finetuned pipeline"]

# %%
file["annotation"]
